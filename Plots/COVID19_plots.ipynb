# %% [markdown]
# # Plot daily data for COVID19
# ## Matt Shields
#
# ### Data from https://github.com/CSSEGISandData/COVID-19.git

# %%
import COVID_plots as covid_plt
# %matplotlib inline

countries = {'China': ['all'],
             'US': ['Colorado','all'],
#              'Italy': ['all'],
            }

df = covid_plt.transform_data(countries)

# %%
covid_plt.plot_data(countries)
